# %% [markdown]
# <br>
# <br>
# <br>
# <br>
#
# # Part 4 : Name Analyze
#
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# <br>
# <br>
# <br>
#
# # Import libarary
#
# <br>
# <br>
# <br>

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from GlobalFunction import *

import time
import re
import nltk
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist
from nltk.stem import PorterStemmer
from nltk.tag import  map_tag
from nltk.tag import pos_tag
from nltk.corpus import stopwords


from wordcloud import WordCloud

pd.set_option('display.width', 500)
pd.set_option('display.max_columns', 100)
pd.set_option('float_format', '{:f}'.format)

sns.set(style="white", color_codes=True)

# %% [markdown]
# <br>
# <br>
# <br>
#
# # Read The Data
#
# <br>
# <br>
# <br>

# %%
df = readCSV("categoriesData.csv")
trainData = readCSV("categoriesTrainData.csv")
df.head()
# Out:
#            ID                                               name        category main_category             deadline             launched       state  backers country      pledged         goal  state_value  hour  day  month  year  weekday  duration  backers_median_category  success_percent_category  pledged_median_category  goal_median_category
# 0  1000002330                    The Songs of Adelaide & Abullah          Poetry    Publishing  2015-10-09 00:00:00  2015-08-11 12:12:28      failed        0      GB     0.000000  1533.950000            0    12   11      8  2015        1        59                 0.036496                  0.405193                 0.013337              0.045598
# 1  1000003930      Greeting From Earth: ZGAC Arts Capsule For ET  Narrative Film  Film & Video  2017-11-01 00:00:00  2017-09-02 04:43:57      failed       15      US  2421.000000 30000.000000            0     4    2      9  2017        5        60                 0.167883                  0.455267                 0.133340              0.318284
# 2  1000004038                                     Where is Hank?  Narrative Film  Film & Video  2013-02-26 00:00:00  2013-01-12 00:20:50      failed        3      US   220.000000 45000.000000            0     0   12      1  2013        5        45                 0.167883                  0.455267                 0.133340              0.318284
# 3  1000007540  ToshiCapital Rekordz Needs Help to Complete Album           Music         Music  2012-04-16 00:00:00  2012-03-17 03:24:11      failed        1      US     1.000000  5000.000000            0     3   17      3  2012        5        30                 0.138686                  0.573300                 0.065204              0.147856
# 4  1000014025                               Monarch Espresso Bar     Restaurants          Food  2016-04-01 00:00:00  2016-02-26 13:38:27  successful      224      US 52375.000000 50000.000000            1    13   26      2  2016        4        35                 0.007299                  0.116545                 0.004295              0.829571

# %% [markdown]
# <br>
# <br>
#
# ## Describe
# <br>
# <br>

# %%
getDescribe(trainData)
# Out:
#           attribute                ID                      name     category main_category             deadline             launched   state       backers country         pledged             goal   state_value          hour           day         month          year       weekday      duration backers_median_category success_percent_category pledged_median_category goal_median_category
# 0             count     238961.000000                    238961       238961        238961               238961               238961  238961 238961.000000  238961   238961.000000    238961.000000 238961.000000 238961.000000 238961.000000 238961.000000 238961.000000 238961.000000 238961.000000           238961.000000            238961.000000           238961.000000        238961.000000
# 1            unique               NaN                    237634          158            15                 2429               238666       2           NaN      19             NaN              NaN           NaN           NaN           NaN           NaN           NaN           NaN           NaN                     NaN                      NaN                     NaN                  NaN
# 2               top               NaN  New EP/Music Development  Documentary  Film & Video  2014-08-08 00:00:00  2014-07-21 21:57:45  failed           NaN      US             NaN              NaN           NaN           NaN           NaN           NaN           NaN           NaN           NaN                     NaN                      NaN                     NaN                  NaN
# 3              freq               NaN                        13        12226         45821                  612                    2  142233           NaN  200553             NaN              NaN           NaN           NaN           NaN           NaN           NaN           NaN           NaN                     NaN                      NaN                     NaN                  NaN
# 4              mean 1074390179.039442                       NaN          NaN           NaN                  NaN                  NaN     NaN    106.420621     NaN     8686.566196     39607.111537      0.404786     13.011985     15.304029      6.542047   2013.292219      2.434891     34.474814                0.142799                 0.431244                0.076864             0.207665
# 5               std  619475910.085835                       NaN          NaN           NaN                  NaN                  NaN     NaN    955.783203     NaN    89553.530567   1089799.099850      0.490852      7.894270      8.776843      3.303666      1.502865      1.747674     13.147914                0.148555                 0.192600                0.079385             0.162388
# 6               min       5971.000000                       NaN          NaN           NaN                  NaN                  NaN     NaN      0.000000     NaN        0.000000         0.010000      0.000000      0.000000      1.000000      1.000000   2009.000000      0.000000      1.000000                0.000000                 0.000000                0.000000             0.000000
# 7               25%  535998693.000000                       NaN          NaN           NaN                  NaN                  NaN     NaN      2.000000     NaN       50.000000      2000.000000      0.000000      5.000000      8.000000      4.000000   2012.000000      1.000000     30.000000                0.051095                 0.294930                0.025060             0.096727
# 8               50% 1075156247.000000                       NaN          NaN           NaN                  NaN                  NaN     NaN     15.000000     NaN      813.000000      5000.000000      0.000000     16.000000     15.000000      7.000000   2014.000000      2.000000     30.000000                0.102190                 0.416229                0.047633             0.147856
# 9               75% 1610960921.000000                       NaN          NaN           NaN                  NaN                  NaN     NaN     61.000000     NaN     4429.990000     15000.000000      1.000000     20.000000     23.000000      9.000000   2015.000000      4.000000     38.000000                0.167883                 0.573300                0.113209             0.267156
# 10              max 2147476221.000000                       NaN          NaN           NaN                  NaN                  NaN     NaN 219382.000000     NaN 20338986.270000 166361390.710000      1.000000     23.000000     31.000000     12.000000   2015.000000      6.000000     92.000000                1.000000                 1.000000                1.000000             1.000000
# 11      null_values          0.000000                         0            0             0                    0                    0       0      0.000000       0        0.000000         0.000000      0.000000      0.000000      0.000000      0.000000      0.000000      0.000000      0.000000                0.000000                 0.000000                0.000000             0.000000
# 12  not_null_values     238961.000000                    238961       238961        238961               238961               238961  238961 238961.000000  238961   238961.000000    238961.000000 238961.000000 238961.000000 238961.000000 238961.000000 238961.000000 238961.000000 238961.000000           238961.000000            238961.000000           238961.000000        238961.000000
# 13            dtype             int64                    object       object        object               object               object  object         int64  object         float64          float64         int64         int64         int64         int64         int64         int64         int64                 float64                  float64                 float64              float64

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
#
# # Part 4.1 : Create WordDataset
#
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# <br>
#
# # Part 4.1.1: Tokenized Name
#
# <br>

# %% [markdown]
# * creating helper function for find pattern in name

# %%
IS_NOT_TIME =  {'miles', 'p', 'km', 'pi',  'b', 'whatever', 'nyc', 'x', 'tiny', 'inc', 'mah','ad'}
IS_URL = arr = {'www','.com','http','https','.org','.eu','.me','.net'}
STOPWORDS_EN = stopwords.words("english")


def isHour(value):
    time_re = re.compile('^(2[0-3]|[01]?[0-9]):([0-5][0-9])$')
    return bool(time_re.match(value)) 

def isDate(value):
    date_re = re.compile('(\d{4})[-\. ](\d{2})[-\. ](\d{2})|(\d{2})[-\. ](\d{2})[-\. ](\d{4})')
    return bool(date_re.match(value)) 

def isYear(value):
    year_re = re.compile('[1-2][0-9]{3}')
    return bool(year_re.match(value))

def isTimeHelper(value):
    return ( isHour(value) |  isDate(value) |  isYear(value)) 

def isTime(value):
    if isTimeHelper(value) == False:
        return False
    for check in IS_NOT_TIME:
        if check in value: 
            return False
    return True

def isNumber(value):
    num_re = re.compile('[-+]?[0-9]*[\.\/\\]?[0-9]+$')
    return bool( num_re.match(value) )

def isUrl(value):
    for c in IS_URL:
        if c in value:
            return True
    
    if ('.' in value) & ('/' in value):
        return True
    
    url_re= re.compile('^(http:\/\/www\.|https:\/\/www\.|http:\/\/|https:\/\/)?[a-z0-9]+([\-\.]{1}[a-z0-9]+)*\.[a-z]{2,5}(:[0-9]{1,5})?(\/.*)?$}')
    return bool(url_re.match(value))
        
def isSymbol(value):
    return len(re.sub(r'[A-Za-z0-9]+', '', value)) != len(value)
        
def isStopWord(value):
    if value in STOPWORDS_EN:
        return True
    return False

# %%
def cleanValueToArr(value):
    res = {''}
    value = nltk.WordNetLemmatizer().lemmatize(value)
    value = nltk.WordPunctTokenizer().tokenize(value)
    for x in value:
        res.update(re.findall(r'[a-z]+', re.sub(r'[^a-z]+',' ',x.lower())))
        res.update(re.findall(r'[0-9]+', re.sub(r'[^0-9]+',' ',x.lower())))
        for c in x.lower().strip():
            if c.isalnum() == False:
                res.update(c)
    res.remove('')
    return res


def tokenizedNameCleanser(arr):
    res= []
    for value in arr:
        if(isUrl(value)):
            res.append('has_url')
        elif isTime(value):
            res.append('has_time')
        elif isTime(value):
            res.append('has_number')
        else:
            for x in cleanValueToArr(value):
                if x != '' :
                    res.append(x)
    return res

# %%
df['tokenized_name'] = df.name.apply(word_tokenize)

# %%
df['clean_tokenized_name'] = df.tokenized_name.apply(lambda x : tokenizedNameCleanser(x))

# %%
trainData = splitData(df,'tokenizedTrainData.csv','tokenizedTestData.csv')

# %% [markdown]
# <br>
# <br>
#
# # Part 4.1.2: create words dataset
#
# <br>
# <br>

# %% [markdown]
# ## Read helper data

# %% [markdown]
# ## positive and negative words dataset
# * link to data : https://www.kaggle.com/syhens/sentiment-words

# %%
negativeWordsData = pd.read_csv('helperData/negative-words.csv')
negativeWordsData.columns = ['negative']
negativeWordsData.negative.apply(lambda x : x.lower())
negativeWordsData.head()
# Out:
#      negative
# 0     2-faces
# 1    abnormal
# 2     abolish
# 3  abominable
# 4  abominably

# %%
negativeData = {}
for index, row in negativeWordsData.iterrows():
    negativeData[row.negative.lower()] =  row.negative.lower()

def isNegativeWord(word):
    try:
        negativeData[word.lower()]
        return 1
    except:
        return 0
    
def negativeWordsCounter(arr):
    counter = 0
    for value in arr:        
        if isNegativeWord(value):
            counter+=1
    return counter

# %%
positiveWordsData = pd.read_csv('helperData/positive-words.csv')
positiveWordsData.columns = ['positive']
positiveWordsData
# Out:
#         positive
# 0        abounds
# 1      abundance
# 2       abundant
# 3     accessable
# 4     accessible
# ...          ...
# 1999    youthful
# 2000        zeal
# 2001      zenith
# 2002        zest
# 2003       zippy
#
# [2004 rows x 1 columns]

# %%
positiveData = {}
for index, row in positiveWordsData.iterrows():
    positiveData[row.positive.lower()] =  row.positive.lower()

def isPositiveWord(word):
    try:
        positiveData[word.lower()]
        return 1
    except:
        return 0
    
def positiveWordsCounter(arr):
    counter = 0
    for value in arr:        
        if isPositiveWord(value):
            counter+=1
    return counter

# %% [markdown]
# ## Frequency words dataset
# * link to data : https://www.kaggle.com/rtatman/english-word-frequency/

# %%
frequencyWordsData = pd.read_csv('helperData/unigram_freq.csv')
frequencyWordsData = frequencyWordsData.rename({'count': 'frequency'}, axis='columns')
frequencyWordsData = getScalingData(frequencyWordsData)
frequencyWordsData.head()
# Out:
#   word  frequency
# 0  the   1.000000
# 1   of   0.568466
# 2  and   0.561796
# 3   to   0.524596
# 4    a   0.392515

# %%
wordFreqValue = {}

for index, row in frequencyWordsData.iterrows():
    wordFreqValue[row.word] =  row.frequency 

def getFreqValue(word):
    try:
        return wordFreqValue[word.lower()]
    except:
        return 0
        
def getNameFreqValue(values):
    sumValues = 0 
    if len(values) ==0:
        return 0
    for x in values:
        sumValues += getFreqValue(x)         
    return sumValues / len(values)

# %% [markdown]
# ## buzzwords words dataset
# * this dataset create by collect data from internet

# %%
buzzwordsData = pd.read_csv('helperData/buzzwords.csv')
buzzwordsData.buzzwords = buzzwordsData.buzzwords.apply(nltk.WordNetLemmatizer().lemmatize)
buzzwordsData.buzzwords = buzzwordsData.buzzwords.apply(lambda x : x.lower())
buzzwordsData.head()
# Out:
#               buzzwords
# 0              business
# 1             analytics
# 2              ballpark
# 3             bandwidth
# 4  business-to-business

# %%
def isBuzzwordWord(word):
    if nltk.WordNetLemmatizer().lemmatize(word).lower() in buzzwordsData.buzzwords.values:
        return 1
    return 0
    
def buzzwordsCounter(name):
    counter = 0
    for value in buzzwordsData.buzzwords.values:
        if(value in nltk.WordNetLemmatizer().lemmatize(name).lower()):
            counter += 1
    return counter

# %% [markdown]
# ## create dataset

# %%
wordSet = []
values = trainData.copy().clean_tokenized_name.values
for arr in values:
    for x in arr:
        if (isTime(x) == False) &  (isUrl(x) == False) &  (isNumber(x) == False) &  (isStopWord(x) == False):
            wordSet.append(x.lower())

# %% [markdown]
# ### find frequency of words

# %%
fdist = FreqDist(wordSet)
wordDataset = pd.DataFrame(list(fdist.items()), columns = ["word","frequency"])
wordDataset = wordDataset.sort_values(by='frequency', ascending=False)
wordDataset.shape
# Out:
# (98519, 2)

# %%
wordDataset.head()
# Out:
#     word  frequency
# 58     -      51604
# 36     '      43575
# 33     :      37800
# 17     !      29246
# 111    ,      19821

# %%
wordDataset['length'] = wordDataset.word.apply(len)

# %% [markdown]
# ### count of success or failed projects per word

# %%
dfSuccess = trainData[trainData.state == 'successful']
data = {}
 
for index, row in dfSuccess.iterrows():
    for value in row.clean_tokenized_name:
        try:
            data[value] = data[value] + 1 
        except: 
            data[value] = 1

# %%
def countOfSuccess(value):
    try:
        return data[value]
    except:
        return 0

wordDataset['count_of_success'] =  wordDataset.apply(lambda row : countOfSuccess(row.word), axis = 1)

# %%
dfFailed = trainData[trainData.state == 'failed']
data = {}
 
for index, row in dfFailed.iterrows():
    for value in row.clean_tokenized_name:
        try:
            data[value] = data[value] + 1 
        except: 
            data[value] = 1

# %%
def countOfFailed(value):
    try:
        return data[value]
    except:
        return 0

wordDataset['count_of_failed'] =  wordDataset.apply(lambda row : countOfFailed(row.word), axis = 1)

# %%
wordDataset['word_percent_success'] =  wordDataset.apply(lambda row : (row.count_of_success) / (row.frequency), axis = 1)

# %%
wordDataset['positive'] =  wordDataset.word.apply(isPositiveWord).astype('int64')

# %%
wordDataset['negative'] =  wordDataset.word.apply(isNegativeWord).astype('int64')

# %%
wordDataset['buzzword'] =  wordDataset.word.apply(isBuzzwordWord).astype('int64')

# %%
wordDataset['frequency_value'] =  wordDataset.word.apply(getFreqValue)

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
#
# # Part 4.2 : WordDataset Visualization
#
# <br>
# <br>
# <br>
# <br>

# %%
def plotWordCloud(column, data=wordDataset):
    words = ' '.join(data)
    values =  data.sort_values(by=column,ascending=False).word.iloc[:100]
    cleaned_word = " ".join([word for word in values])
    wordcloud = WordCloud(background_color='white',
                      width=2500,
                      height=2000,
                     ).generate(cleaned_word)
    plt.figure(1,figsize=(12, 12))
    plt.imshow(wordcloud,interpolation='bilinear')
    plt.axis('off')
    plt.show()

# %%
plotWordCloud('frequency')

# %%
plotWordCloud('count_of_success')

# %%
plotWordCloud('word_percent_success', data=wordDataset[wordDataset.frequency >= 100])

# %%
buzzword = wordDataset[wordDataset.buzzword == 1].word_percent_success.values
frequency = wordDataset[wordDataset.frequency_value >0].word_percent_success.values
positive = wordDataset[wordDataset.positive == 1].word_percent_success.values
negative = wordDataset[wordDataset.negative == 1].word_percent_success.values

fig , ((ax1,ax2),(ax3,ax4)) = plt.subplots(nrows=2,ncols=2,figsize=(17,15))

fig.tight_layout(pad=12.0)
sns.distplot(negative, bins=30, norm_hist=True, color = 'g', ax=ax1 , axlabel='negative')
sns.distplot(buzzword, bins=30, norm_hist=True, color = 'c', ax=ax2, axlabel='buzzword')
sns.distplot(frequency, bins=30, norm_hist=True, color = 'b', ax=ax3, axlabel='frequency')
sns.distplot(positive, bins=30, norm_hist=True, color = 'r', ax=ax4, axlabel='positive')

plt.show()

# %%
wordDataset[wordDataset.frequency >= 100].word_percent_success.hist(bins= 20, color = 'c', figsize=(12,6))
plt.show()

# %%
plotCorr(wordDataset)
# Out:
# <style  type="text/css" >
#     #T_8e49e0ee_7ca8_11ea_85a1_9cda3ef10a76row0_col0 {
#             background-color:  #084081;
#             color:  #f1f1f1;
#         }    #T_8e49e0ee_7ca8_11ea_85a1_9cda3ef10a76row0_col1 {
#             background-color:  #f0f9e9;
#             color:  #000000;
#         }    #T_8e49e0ee_7ca8_11ea_85a1_9cda3ef10a76row0_col2 {
#             background-color:  #084182;
#             color:  #f1f1f1;
#         }    #T_8e49e0ee_7ca8_11ea_85a1_9cda3ef10a76row0_col3 {
#             background-color:  #084081;
#             color:  #f1f1f1;
#         }    #T_8e49e0ee_7ca8_11ea_85a1_9cda3ef10a76row0_col4 {
#             background-color:  #f2faeb;
#             color:  #000000;
#         }    #T_8e49e0ee_7ca8_11ea_85a1_9cda3ef10a76row0_col5 {
#             background-color:  #f3faec;
#             color:  #000000;
#         }    #T_8e49e0ee_7ca8_11ea_85a1_9cda3ef10a76row0_col6 {
#             background-color:  #f4fbed;
#             color:  #000000;
#         }    #T_8e49e0ee_7ca8_11ea_85a1_9cda3ef10a76row0_col7 {
#             background-color:  #f3fbed;
#             color:  #000000;
#         }    #T_8e49e0ee_7ca8_11ea_85a1_9cda3ef10a76row0_col8 {
#             background-color:  #d2edcc;
#             color:  #000000;
#         }    #T_8e49e0ee_7ca8_11ea_85a1_9cda3ef10a76row1_col0 {
#             background-color:  #f7fcf0;
#             color:  #000000;
#         }    #T_8e49e0ee_7ca8_11ea_85a1_9cda3ef10a76row1_col1 {
#             background-color:  #084081;
#             color:  #f1f1f1;
#         }    #T_8e49e0ee_7ca8_11ea_85a1_9cda3ef10a76row1_col2 {
#             background-color:  #f7fcf0;
#             color:  #000000;
#         }    #T_8e49e0ee_7ca8_11ea_85a1_9cda3ef10a76row1_col3 {
#             background-color:  #f7fcf0;
#             color:  #000000;
#         }    #T_8e49e0ee_7ca8_11ea_85a1_9cda3ef10a76row1_col4 {
#             background-color:  #f7fcf0;
#             color:  #000000;
#         }    #T_8e49e0ee_7ca8_11ea_85a1_9cda3ef10a76row1_col5 {
#             background-color:  #f1f9ea;
#             color:  #000000;
#         }    #T_8e49e0ee_7ca8_11ea_85a1_9cda3ef10a76row1_col6 {
#             background-color:  #f5fbee;
#             color:  #000000;
#         }    #T_8e49e0ee_7ca8_11ea_85a1_9cda3ef10a76row1_col7 {
#             background-color:  #f6fcef;
#             color:  #000000;
#         }    #T_8e49e0ee_7ca8_11ea_85a1_9cda3ef10a76row1_col8 {
#             background-color:  #f7fcf0;
#             color:  #000000;
#         }    #T_8e49e0ee_7ca8_11ea_85a1_9cda3ef10a76row2_col0 {
#             background-color:  #084182;
#             color:  #f1f1f1;
#         }    #T_8e49e0ee_7ca8_11ea_85a1_9cda3ef10a76row2_col1 {
#             background-color:  #eff9e9;
#             color:  #000000;
#         }    #T_8e49e0ee_7ca8_11ea_85a1_9cda3ef10a76row2_col2 {
#             background-color:  #084081;
#             color:  #f1f1f1;
#         }    #T_8e49e0ee_7ca8_11ea_85a1_9cda3ef10a76row2_col3 {
#             background-color:  #084586;
#             color:  #f1f1f1;
#         }    #T_8e49e0ee_7ca8_11ea_85a1_9cda3ef10a76row2_col4 {
#             background-color:  #f1faeb;
#             color:  #000000;
#         }    #T_8e49e0ee_7ca8_11ea_85a1_9cda3ef10a76row2_col5 {
#             background-color:  #f3faec;
#             color:  #000000;
#         }    #T_8e49e0ee_7ca8_11ea_85a1_9cda3ef10a76row2_col6 {
#             background-color:  #f4fbed;
#             color:  #000000;
#         }    #T_8e49e0ee_7ca8_11ea_85a1_9cda3ef10a76row2_col7 {
#             background-color:  #f4fbed;
#             color:  #000000;
#         }    #T_8e49e0ee_7ca8_11ea_85a1_9cda3ef10a76row2_col8 {
#             background-color:  #d3eecd;
#             color:  #000000;
#         }    #T_8e49e0ee_7ca8_11ea_85a1_9cda3ef10a76row3_col0 {
#             background-color:  #084081;
#             color:  #f1f1f1;
#         }    #T_8e49e0ee_7ca8_11ea_85a1_9cda3ef10a76row3_col1 {
#             background-color:  #f0f9e9;
#             color:  #000000;
#         }    #T_8e49e0ee_7ca8_11ea_85a1_9cda3ef10a76row3_col2 {
#             background-color:  #084586;
#             color:  #f1f1f1;
#         }    #T_8e49e0ee_7ca8_11ea_85a1_9cda3ef10a76row3_col3 {
#             background-color:  #084081;
#             color:  #f1f1f1;
#         }    #T_8e49e0ee_7ca8_11ea_85a1_9cda3ef10a76row3_col4 {
#             background-color:  #f3fbed;
#             color:  #000000;
#         }    #T_8e49e0ee_7ca8_11ea_85a1_9cda3ef10a76row3_col5 {
#             background-color:  #f2faeb;
#             color:  #000000;
#         }    #T_8e49e0ee_7ca8_11ea_85a1_9cda3ef10a76row3_col6 {
#             background-color:  #f4fbed;
#             color:  #000000;
#         }    #T_8e49e0ee_7ca8_11ea_85a1_9cda3ef10a76row3_col7 {
#             background-color:  #f3fbed;
#             color:  #000000;
#         }    #T_8e49e0ee_7ca8_11ea_85a1_9cda3ef10a76row3_col8 {
#             background-color:  #d1edca;
#             color:  #000000;
#         }    #T_8e49e0ee_7ca8_11ea_85a1_9cda3ef10a76row4_col0 {
#             background-color:  #f0f9e9;
#             color:  #000000;
#         }    #T_8e49e0ee_7ca8_11ea_85a1_9cda3ef10a76row4_col1 {
#             background-color:  #eef8e7;
#             color:  #000000;
#         }    #T_8e49e0ee_7ca8_11ea_85a1_9cda3ef10a76row4_col2 {
#             background-color:  #eff9e9;
#             color:  #000000;
#         }    #T_8e49e0ee_7ca8_11ea_85a1_9cda3ef10a76row4_col3 {
#             background-color:  #f1f9ea;
#             color:  #000000;
#         }    #T_8e49e0ee_7ca8_11ea_85a1_9cda3ef10a76row4_col4 {
#             background-color:  #084081;
#             color:  #f1f1f1;
#         }    #T_8e49e0ee_7ca8_11ea_85a1_9cda3ef10a76row4_col5 {
#             background-color:  #f6fbef;
#             color:  #000000;
#         }    #T_8e49e0ee_7ca8_11ea_85a1_9cda3ef10a76row4_col6 {
#             background-color:  #f4fbed;
#             color:  #000000;
#         }    #T_8e49e0ee_7ca8_11ea_85a1_9cda3ef10a76row4_col7 {
#             background-color:  #f7fcf0;
#             color:  #000000;
#         }    #T_8e49e0ee_7ca8_11ea_85a1_9cda3ef10a76row4_col8 {
#             background-color:  #ebf7e5;
#             color:  #000000;
#         }    #T_8e49e0ee_7ca8_11ea_85a1_9cda3ef10a76row5_col0 {
#             background-color:  #eef9e8;
#             color:  #000000;
#         }    #T_8e49e0ee_7ca8_11ea_85a1_9cda3ef10a76row5_col1 {
#             background-color:  #e5f5e0;
#             color:  #000000;
#         }    #T_8e49e0ee_7ca8_11ea_85a1_9cda3ef10a76row5_col2 {
#             background-color:  #eff9e9;
#             color:  #000000;
#         }    #T_8e49e0ee_7ca8_11ea_85a1_9cda3ef10a76row5_col3 {
#             background-color:  #eef8e7;
#             color:  #000000;
#         }    #T_8e49e0ee_7ca8_11ea_85a1_9cda3ef10a76row5_col4 {
#             background-color:  #f4fbed;
#             color:  #000000;
#         }    #T_8e49e0ee_7ca8_11ea_85a1_9cda3ef10a76row5_col5 {
#             background-color:  #084081;
#             color:  #f1f1f1;
#         }    #T_8e49e0ee_7ca8_11ea_85a1_9cda3ef10a76row5_col6 {
#             background-color:  #f7fcf0;
#             color:  #000000;
#         }    #T_8e49e0ee_7ca8_11ea_85a1_9cda3ef10a76row5_col7 {
#             background-color:  #e8f6e2;
#             color:  #000000;
#         }    #T_8e49e0ee_7ca8_11ea_85a1_9cda3ef10a76row5_col8 {
#             background-color:  #e1f3dc;
#             color:  #000000;
#         }    #T_8e49e0ee_7ca8_11ea_85a1_9cda3ef10a76row6_col0 {
#             background-color:  #f0f9e9;
#             color:  #000000;
#         }    #T_8e49e0ee_7ca8_11ea_85a1_9cda3ef10a76row6_col1 {
#             background-color:  #e9f7e3;
#             color:  #000000;
#         }    #T_8e49e0ee_7ca8_11ea_85a1_9cda3ef10a76row6_col2 {
#             background-color:  #f1f9ea;
#             color:  #000000;
#         }    #T_8e49e0ee_7ca8_11ea_85a1_9cda3ef10a76row6_col3 {
#             background-color:  #f0f9e9;
#             color:  #000000;
#         }    #T_8e49e0ee_7ca8_11ea_85a1_9cda3ef10a76row6_col4 {
#             background-color:  #f2faeb;
#             color:  #000000;
#         }    #T_8e49e0ee_7ca8_11ea_85a1_9cda3ef10a76row6_col5 {
#             background-color:  #f7fcf0;
#             color:  #000000;

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
#
# # Part 4.3 : Create Featuers
#
# <br>
# <br>
# <br>
# <br>

# %%
df['name_count_words'] = df.tokenized_name.apply(len) 
df['clean_name_count_words'] = df.clean_tokenized_name.apply(len)

# %%
def getWordsLenMean(arr):
    sumLen = 0 
    for value in arr:
        sumLen += len(value)
    try:
        return sumLen / len(arr)
    except:
        return 0 
            
df['words_len_mean'] =  df.tokenized_name.apply(getWordsLenMean)

# %%
def numberCounter(arr):
    counter = 0 
    for x in arr:
        if isNumber(x):
            counter+=1
    return counter

df['name_number_count'] = df.clean_tokenized_name.apply(lambda x : numberCounter(x))

# %%
def timeCounter(arr):
    counter = 0 
    for x in arr:
        if isTime(x):
            counter+=1
    return counter

df['name_time_count'] = df.tokenized_name.apply(lambda x : timeCounter(x))

# %%
def urlCounter(arr):
    counter = 0 
    for x in arr:
        if isUrl(x):
            counter+=1
    return counter

df['name_url_count'] = df.tokenized_name.apply(lambda x : urlCounter(x))

# %%
def stopWordCounter(arr):
    counter = 0
    for x in arr:
        if isStopWord(x):
            counter += 1
    return counter
        
df['stopword_count'] = df.clean_tokenized_name.apply(stopWordCounter)

# %%
def symbolCounter(arr):
    counter = 0
    for x in arr:
        if isSymbol(x):
            counter += 1
    return counter
        
df['symbol_count'] = df.clean_tokenized_name.apply(symbolCounter)

# %%
df['name_len'] = df.name.str.len()

# %%
df['name_is_question'] = (df.name.str[-1] == '?').astype(int)

# %%
df['name_is_exclamation'] = (df.name.str[-1] == '!').astype(int)

# %%
df['name_is_upper'] = df.name.str.isupper().astype(float)

# %%
def countVowelstoLettersRatio(s):
    s = str(s)
    count = 1  
    vowels = 0
    for i in s:
        if i.isalpha():
            count = count + 1
            if i in 'aeiou':
                vowels = vowels + 1
    return (vowels / count)

df['name_vowel_ratio'] = df.name.apply(countVowelstoLettersRatio)

# %%
df['name_negative_count'] = df.clean_tokenized_name.apply(lambda arr : negativeWordsCounter(arr))

# %%
df['name_positive_count'] = df.clean_tokenized_name.apply(lambda arr : positiveWordsCounter(arr))

# %%
# performance are low , if not necessary do not run
df['name_buzzwords_count'] = df.name.apply(buzzwordsCounter)

# %%
df['name_freq_value'] = df.clean_tokenized_name.apply(lambda arr : getNameFreqValue(arr))

# %%
wordSuccessValue = {}

for index, row in wordDataset[wordDataset.frequency >= 3].iterrows():
    wordSuccessValue[row.word] =  row.word_percent_success


def getSuccessValueByName(values):
    sumValues = 0 
    lenValues= 0
    for x in values:
        if (isTime(x) == False) &  (isUrl(x) == False) &  (isNumber(x) == False) :
            try:
                sumValues += wordSuccessValue[x]
                lenValues+= 1
            except:
                sumValues +=0
    try:
        return sumValues / lenValues
    except:
        return 0
    
df['name_success_value'] = df.clean_tokenized_name.apply(lambda x : getSuccessValueByName(x))

# %%
def getPositiveValueByName(arr):    
    sumValues = 0
    for value in arr:
        if(isPositiveWord(value)):
            try:
                sumValues += wordSuccessValue[x]
            except:
                sumValues += 0
    try:
        return sumValues / len(arr)
    except:
        return 0    

df['name_posotive_value'] = df.clean_tokenized_name.apply(lambda arr : getPositiveValueByName(arr))

# %%
def getNegativeValueByName(arr):    
    sumValues = 0
    for value in arr:
        if(isNegativeWord(value)):
            try:
                sumValues += wordSuccessValue[x]
            except:
                sumValues += 0
    try:
        return sumValues / len(arr)
    except:
        return 0    

df['name_negative_value'] = df.clean_tokenized_name.apply(lambda arr : getNegativeValueByName(arr))

# %%
writeCSV(df,'fullData.csv')
trainData = splitData(df,'TrainData.csv','TestData.csv')
trainData.shape
# Out:
# (238961, 44)

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
#
# # Part 4.4 : Data Visualization
#
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# <br>
# <br>
# <br>
#
# ## describe full train data
#
# <br>
# <br>
# <br>

# %%
trainData.describe()
# Out:
#                      ID       backers         pledged             goal   state_value          hour           day         month          year       weekday      duration  backers_median_category  success_percent_category  pledged_median_category  goal_median_category  name_count_words  clean_name_count_words  words_len_mean  name_number_count  name_time_count  name_url_count  stopword_count  symbol_count      name_len  name_is_question  name_is_exclamation  name_is_upper  name_vowel_ratio  \
# count     238961.000000 238961.000000   238961.000000    238961.000000 238961.000000 238961.000000 238961.000000 238961.000000 238961.000000 238961.000000 238961.000000            238961.000000             238961.000000            238961.000000         238961.000000     238961.000000           238961.000000   238961.000000      238961.000000    238961.000000   238961.000000   238961.000000 238961.000000 238961.000000     238961.000000        238961.000000  238961.000000     238961.000000
# mean  1074390179.039442    106.420621     8686.566196     39607.111537      0.404786     13.011985     15.304029      6.542047   2013.292219      2.434891     34.474814                 0.142799                  0.431244                 0.076864              0.207665          6.409607                6.794280        5.018167           0.231963         0.026540        0.003879        1.329811      5.674528     34.167793          0.004942             0.085303       0.039894          0.309211
# std    619475910.085835    955.783203    89553.530567   1089799.099850      0.490852      7.894270      8.776843      3.303666      1.502865      1.747674     13.147914                 0.148555                  0.192600                 0.079385              0.162388          3.338631                3.592525        1.645670           0.615536         0.163035        0.063561        1.348527      2.742090     15.976884          0.070127             0.279332       0.195709          0.089829
# min         5971.000000      0.000000        0.000000         0.010000      0.000000      0.000000      1.000000      1.000000   2009.000000      0.000000      1.000000                 0.000000                  0.000000                 0.000000              0.000000          1.000000                1.000000        1.000000           0.000000         0.000000        0.000000        0.000000      1.000000      1.000000          0.000000             0.000000       0.000000          0.000000
# 25%    535998693.000000      2.000000       50.000000      2000.000000      0.000000      5.000000      8.000000      4.000000   2012.000000      1.000000     30.000000                 0.051095                  0.294930                 0.025060              0.096727          4.000000                4.000000        4.000000           0.000000         0.000000        0.000000        0.000000      3.000000     21.000000          0.000000             0.000000       0.000000          0.280000
# 50%   1075156247.000000     15.000000      813.000000      5000.000000      0.000000     16.000000     15.000000      7.000000   2014.000000      2.000000     30.000000                 0.102190                  0.416229                 0.047633              0.147856          6.000000                6.000000        4.700000           0.000000         0.000000        0.000000        1.000000      5.000000     33.000000          0.000000             0.000000       0.000000          0.325000
# 75%   1610960921.000000     61.000000     4429.990000     15000.000000      1.000000     20.000000     23.000000      9.000000   2015.000000      4.000000     38.000000                 0.167883                  0.573300                 0.113209              0.267156          9.000000                9.000000        5.666667           0.000000         0.000000        0.000000        2.000000      8.000000     48.000000          0.000000             0.000000       0.000000          0.363636
# max   2147476221.000000 219382.000000 20338986.270000 166361390.710000      1.000000     23.000000     31.000000     12.000000   2015.000000      6.000000     92.000000                 1.000000                  1.000000                 1.000000              1.000000         57.000000               57.000000       45.000000          32.000000         2.000000        2.000000       14.000000     27.000000     85.000000          1.000000             1.000000       1.000000          0.625000
#
#        name_negative_count  name_positive_count  name_buzzwords_count  name_freq_value  name_success_value  name_posotive_value  name_negative_value
# count        238961.000000        238961.000000         238961.000000    238961.000000       238961.000000        238961.000000        238961.000000
# mean              0.152874             0.203000              0.262332         0.080757            0.419750             0.015100             0.012889
# std               0.404808             0.465991              0.556395         0.098464            0.106205             0.040756             0.041841
# min               0.000000             0.000000              0.000000         0.000000            0.000000             0.000000             0.000000
# 25%               0.000000             0.000000              0.000000         0.003471            0.380251             0.000000             0.000000
# 50%               0.000000             0.000000              0.000000         0.043453            0.428205             0.000000             0.000000
# 75%               0.000000             0.000000              0.000000         0.129379            0.476389             0.000000             0.000000
# max               5.000000             5.000000              7.000000         0.666718            1.000000             0.481297             0.481297

# %% [markdown]
# <br>
# <br>
# <br>
#
# ## visualtion full train data
#
# <br>
# <br>
# <br>

# %%
def plotColumnStateCompare(data,column, hue = 'state'):
    fig, ax = plt.subplots(1,1, figsize=(12,10))
    plt.subplot(212)
    ax = sns.countplot(x=column, hue=hue, data=data , palette='GnBu' )
    ax.set_title("Projects count by " + str(column), fontsize=22)
    ax.set_xlabel(str(column), fontsize=17)
    ax.set_ylabel("Count", fontsize=17),
    ax.legend(loc='upper right')
    plt.subplots_adjust(hspace = 0.4)
    plt.show()

# %%
data = trainData.copy()
data.words_len_mean = data.words_len_mean.astype('int64')
plotColumnStateCompare(data, 'words_len_mean')

# %%
plotColumnStateCompare(trainData, 'clean_name_count_words')

# %%
data = trainData[['state','backers','name_success_value','name_time_count','name_url_count','stopword_count',
                  'symbol_count']].copy()
sns.pairplot(data, hue='state', palette = 'GnBu')
plt.show()

# %%
sns.lmplot( x="name_success_value", y="words_len_mean", data=trainData, fit_reg=False, hue='state',
           legend=False,palette='GnBu')
plt.legend(loc='lower right')
plt.show()

# %%
sns.lmplot( x="backers", y="words_len_mean", data=trainData, fit_reg=False, hue='state',
           legend=False,palette='GnBu')
plt.legend(loc='lower right')
plt.show()

# %%
g = sns.FacetGrid(trainData, col="state", hue="name_is_question", palette='GnBu', height=5)
g.map(plt.scatter, "name_success_value", "backers", alpha=.7, linewidth=.5, edgecolor="white")
g.add_legend()
plt.show()

# %%
g = sns.FacetGrid(trainData, col="state", hue="name_is_exclamation", palette='GnBu', height=5)
g.map(plt.scatter, "name_success_value", "backers", alpha=.7, linewidth=.5, edgecolor="white")
g.add_legend()
plt.show()

# %%
g = sns.FacetGrid(trainData, col="state", hue="name_is_upper", palette='GnBu', height=5)
g.map(plt.scatter, "name_success_value", "backers", alpha=.7, linewidth=.5, edgecolor="white")
g.add_legend()
plt.show()

# %%
g = sns.FacetGrid(trainData, col="name_is_exclamation",row = 'main_category' ,hue="state", palette='GnBu', height=5)
g.map(plt.scatter, "name_success_value", "backers", alpha=.7, linewidth=.5, edgecolor="white")
g.add_legend()
plt.show()

# %%
plotCorr(trainData)
# Out:
# <style  type="text/css" >
#     #T_2cd94f58_7caa_11ea_95de_9cda3ef10a76row0_col0 {
#             background-color:  #084081;
#             color:  #f1f1f1;
#         }    #T_2cd94f58_7caa_11ea_95de_9cda3ef10a76row0_col1 {
#             background-color:  #f3fbed;
#             color:  #000000;
#         }    #T_2cd94f58_7caa_11ea_95de_9cda3ef10a76row0_col2 {
#             background-color:  #f3fbed;
#             color:  #000000;
#         }    #T_2cd94f58_7caa_11ea_95de_9cda3ef10a76row0_col3 {
#             background-color:  #f3faec;
#             color:  #000000;
#         }    #T_2cd94f58_7caa_11ea_95de_9cda3ef10a76row0_col4 {
#             background-color:  #e2f4dd;
#             color:  #000000;
#         }    #T_2cd94f58_7caa_11ea_95de_9cda3ef10a76row0_col5 {
#             background-color:  #e1f4dc;
#             color:  #000000;
#         }    #T_2cd94f58_7caa_11ea_95de_9cda3ef10a76row0_col6 {
#             background-color:  #f0f9e9;
#             color:  #000000;
#         }    #T_2cd94f58_7caa_11ea_95de_9cda3ef10a76row0_col7 {
#             background-color:  #eaf7e4;
#             color:  #000000;
#         }    #T_2cd94f58_7caa_11ea_95de_9cda3ef10a76row0_col8 {
#             background-color:  #d3eecc;
#             color:  #000000;
#         }    #T_2cd94f58_7caa_11ea_95de_9cda3ef10a76row0_col9 {
#             background-color:  #e2f4dd;
#             color:  #000000;
#         }    #T_2cd94f58_7caa_11ea_95de_9cda3ef10a76row0_col10 {
#             background-color:  #d8f0d3;
#             color:  #000000;
#         }    #T_2cd94f58_7caa_11ea_95de_9cda3ef10a76row0_col11 {
#             background-color:  #f1f9ea;
#             color:  #000000;
#         }    #T_2cd94f58_7caa_11ea_95de_9cda3ef10a76row0_col12 {
#             background-color:  #c6e9c2;
#             color:  #000000;
#         }    #T_2cd94f58_7caa_11ea_95de_9cda3ef10a76row0_col13 {
#             background-color:  #eff9e9;
#             color:  #000000;
#         }    #T_2cd94f58_7caa_11ea_95de_9cda3ef10a76row0_col14 {
#             background-color:  #c5e8c2;
#             color:  #000000;
#         }    #T_2cd94f58_7caa_11ea_95de_9cda3ef10a76row0_col15 {
#             background-color:  #bae4bd;
#             color:  #000000;
#         }    #T_2cd94f58_7caa_11ea_95de_9cda3ef10a76row0_col16 {
#             background-color:  #c0e6c0;
#             color:  #000000;
#         }    #T_2cd94f58_7caa_11ea_95de_9cda3ef10a76row0_col17 {
#             background-color:  #bae4bd;
#             color:  #000000;
#         }    #T_2cd94f58_7caa_11ea_95de_9cda3ef10a76row0_col18 {
#             background-color:  #e1f3dc;
#             color:  #000000;
#         }    #T_2cd94f58_7caa_11ea_95de_9cda3ef10a76row0_col19 {
#             background-color:  #ecf8e6;
#             color:  #000000;
#         }    #T_2cd94f58_7caa_11ea_95de_9cda3ef10a76row0_col20 {
#             background-color:  #e8f6e2;
#             color:  #000000;
#         }    #T_2cd94f58_7caa_11ea_95de_9cda3ef10a76row0_col21 {
#             background-color:  #bfe6bf;
#             color:  #000000;
#         }    #T_2cd94f58_7caa_11ea_95de_9cda3ef10a76row0_col22 {
#             background-color:  #c5e8c2;
#             color:  #000000;
#         }    #T_2cd94f58_7caa_11ea_95de_9cda3ef10a76row0_col23 {
#             background-color:  #dff2da;
#             color:  #000000;
#         }    #T_2cd94f58_7caa_11ea_95de_9cda3ef10a76row0_col24 {
#             background-color:  #ecf8e6;
#             color:  #000000;
#         }    #T_2cd94f58_7caa_11ea_95de_9cda3ef10a76row0_col25 {
#             background-color:  #ddf2d7;
#             color:  #000000;
#         }    #T_2cd94f58_7caa_11ea_95de_9cda3ef10a76row0_col26 {
#             background-color:  #9bd8b9;
#             color:  #000000;
#         }    #T_2cd94f58_7caa_11ea_95de_9cda3ef10a76row0_col27 {
#             background-color:  #9bd8b9;
#             color:  #000000;
#         }    #T_2cd94f58_7caa_11ea_95de_9cda3ef10a76row0_col28 {
#             background-color:  #ebf7e5;
#             color:  #000000;
#         }    #T_2cd94f58_7caa_11ea_95de_9cda3ef10a76row0_col29 {
#             background-color:  #eef8e7;
#             color:  #000000;
#         }    #T_2cd94f58_7caa_11ea_95de_9cda3ef10a76row0_col30 {
#             background-color:  #f2faeb;
#             color:  #000000;
#         }    #T_2cd94f58_7caa_11ea_95de_9cda3ef10a76row0_col31 {
#             background-color:  #d5eece;
#             color:  #000000;
#         }    #T_2cd94f58_7caa_11ea_95de_9cda3ef10a76row0_col32 {
#             background-color:  #ceecc8;
#             color:  #000000;
#         }    #T_2cd94f58_7caa_11ea_95de_9cda3ef10a76row0_col33 {
#             background-color:  #eff9e9;
#             color:  #000000;
#         }    #T_2cd94f58_7caa_11ea_95de_9cda3ef10a76row0_col34 {
#             background-color:  #e8f6e2;
#             color:  #000000;
#         }    #T_2cd94f58_7caa_11ea_95de_9cda3ef10a76row1_col0 {
#             background-color:  #f6fcef;
#             color:  #000000;
#         }    #T_2cd94f58_7caa_11ea_95de_9cda3ef10a76row1_col1 {
#             background-color:  #084081;
#             color:  #f1f1f1;
#         }    #T_2cd94f58_7caa_11ea_95de_9cda3ef10a76row1_col2 {
#             background-color:  #2586bb;
#             color:  #000000;
#         }    #T_2cd94f58_7caa_11ea_95de_9cda3ef10a76row1_col3 {
#             background-color:  #f2faeb;
#             color:  #000000;
#         }    #T_2cd94f58_7caa_11ea_95de_9cda3ef10a76row1_col4 {
#             background-color:  #d1edcb;
#             color:  #000000;
#         }    #T_2cd94f58_7caa_11ea_95de_9cda3ef10a76row1_col5 {
#             background-color:  #e1f3dc;
#             color:  #000000;
#         }    #T_2cd94f58_7caa_11ea_95de_9cda3ef10a76row1_col6 {
#             background-color:  #f1faeb;
#             color:  #000000;
#         }    #T_2cd94f58_7caa_11ea_95de_9cda3ef10a76row1_col7 {
#             background-color:  #ebf7e5;
#             color:  #000000;
#         }    #T_2cd94f58_7caa_11ea_95de_9cda3ef10a76row1_col8 {
#             background-color:  #d1edca;
#             color:  #000000;
#         }    #T_2cd94f58_7caa_11ea_95de_9cda3ef10a76row1_col9 {
#             background-color:  #e5f5e0;
#             color:  #000000;
#         }    #T_2cd94f58_7caa_11ea_95de_9cda3ef10a76row1_col10 {
#             background-color:  #d9f0d3;
#             color:  #000000;
#         }    #T_2cd94f58_7caa_11ea_95de_9cda3ef10a76row1_col11 {
#             background-color:  #e3f4de;
#             color:  #000000;
#         }    #T_2cd94f58_7caa_11ea_95de_9cda3ef10a76row1_col12 {
#             background-color:  #c4e8c1;
#             color:  #000000;
#         }    #T_2cd94f58_7caa_11ea_95de_9cda3ef10a76row1_col13 {
#             background-color:  #e2f4dd;
#             color:  #000000;
#         }    #T_2cd94f58_7caa_11ea_95de_9cda3ef10a76row1_col14 {
#             background-color:  #bae4bd;
#             color:  #000000;
#         }    #T_2cd94f58_7caa_11ea_95de_9cda3ef10a76row1_col15 {
#             background-color:  #b6e3bb;
#             color:  #000000;
#         }    #T_2cd94f58_7caa_11ea_95de_9cda3ef10a76row1_col16 {
#             background-color:  #bde5be;
#             color:  #000000;
#         }    #T_2cd94f58_7caa_11ea_95de_9cda3ef10a76row1_col17 {
#             background-color:  #bae4bd;
#             color:  #000000;
#         }    #T_2cd94f58_7caa_11ea_95de_9cda3ef10a76row1_col18 {
#             background-color:  #def2d9;
#             color:  #000000;
#         }    #T_2cd94f58_7caa_11ea_95de_9cda3ef10a76row1_col19 {
#             background-color:  #eef8e7;
#             color:  #000000;
#         }    #T_2cd94f58_7caa_11ea_95de_9cda3ef10a76row1_col20 {
#             background-color:  #e9f6e3;
#             color:  #000000;
#         }    #T_2cd94f58_7caa_11ea_95de_9cda3ef10a76row1_col21 {
#             background-color:  #bfe6bf;
#             color:  #000000;
#         }    #T_2cd94f58_7caa_11ea_95de_9cda3ef10a76row1_col22 {
#             background-color:  #c2e7c0;
#             color:  #000000;
#         }    #T_2cd94f58_7caa_11ea_95de_9cda3ef10a76row1_col23 {
#             background-color:  #dcf1d6;
#             color:  #000000;
#         }    #T_2cd94f58_7caa_11ea_95de_9cda3ef10a76row1_col24 {
#             background-color:  #

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
#
#
# # conclusion :
#
#
# ## * try to use in short words and short name (not too short)
#
# ## * prefer using in frequency words
#
#
# ## * symbol and stopwords are good, but not too much
#
# ## * symbol and stopwords are good, but not too much
#
# ##  * name that ent with exclamation get more backers then name that end with question and name is upper
#
# <br>
# <br>
# <br>
# <br>
